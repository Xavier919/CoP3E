# %% [markdown]
# # CoP3E features selection

# %% [markdown]
# ### Import packages

# %%
#packages
from modules.feature_calculator import FeatureCalculator
import pickle

# %% [markdown]
# ### Project specific tools

# %%
#class
fc = FeatureCalculator()

# %%
#dataset
ensembl_pseudogene = pickle.load(open('ensembl_pseudogene.pkl', 'rb'))
datasets = fc.datasets(ensembl_pseudogene)

# %%
cnts_dict = fc.get_cnts_dict(datasets)
all_cnts = fc.get_all_cnts(cnts_dict)
frqs_dict = fc.get_frqs_dict(datasets)

# %%
#features chi2 calculation
chi2 = fc.get_chi2(all_cnts)

# %%
#selecting features with chi2 score above 75.
selected_features = fc.get_features(chi2, 75)
pickle.dump(selected_features, open('selected_features.pkl', 'wb'))

# %%
pickle.dump(datasets, open('datasets.pkl', 'wb'))
pickle.dump(frqs_dict, open('frqs_dict.pkl', 'wb'))

# %% [markdown]
# ### Features

# %%
features_df = fc.get_features_df(chi2, frqs_dict)
print(features_df[:50])
# Out:
#                        chi2        p_value  c_mean_frq  n_mean_frq
# synonymous_TGA   725.512387  8.472428e-160    0.583524    0.438247
# dnt_TA           698.359879  6.797665e-154    0.038489    0.045830
# degeneracy_low   571.145523  3.163262e-126    0.384019    0.363264
# codons_ATG       544.906071  1.614864e-120    0.023351    0.018997
# dnt_GA           472.266048  1.029586e-104    0.086733    0.079157
# codons_TAG       321.278223   7.629188e-72    0.006598    0.008972
# synonymous_TAG   309.386356   2.971004e-69    0.172861    0.180246
# codons_TCT       278.222007   1.832551e-62    0.014942    0.019142
# codons_TTA       271.981468   4.198196e-61    0.009013    0.010901
# nt_G             267.057357   4.968877e-60    0.257448    0.251175
# dnt_TG           260.565136   1.292202e-58    0.089496    0.084344
# codons_ATA       251.045467   1.536456e-56    0.009521    0.011745
# codons_TAA       233.778205   8.941444e-53    0.010147    0.011889
# synonymous_TAA   225.415506   5.959190e-51    0.239183    0.221238
# codons_CTA       222.117827   3.122061e-50    0.009795    0.012096
# codons_TGA       221.116690   5.161879e-50    0.024132    0.021600
# codons_GAA       216.999534   4.082083e-49    0.028185    0.024619
# dnt_CT           213.890575   1.945757e-48    0.068900    0.076736
# nt_C             206.617786   7.512715e-47    0.226704    0.235708
# codons_TGG       205.996642   1.026418e-46    0.026636    0.025259
# synonymous_TCT   201.059803   1.226202e-45    0.178775    0.211897
# codons_GAG       190.299329   2.735232e-43    0.022388    0.020495
# synonymous_CGC   184.398822   5.309351e-42    0.065417    0.066882
# nt_T             182.395873   1.453191e-41    0.225753    0.234281
# codons_AGA       160.839056   7.418698e-37    0.029566    0.026141
# codons_AAG       160.055281   1.100449e-36    0.030498    0.026098
# synonymous_TTA   149.080853   2.753388e-34    0.099832    0.107044
# degeneracy_high  145.281650   1.863741e-33    0.246927    0.256790
# synonymous_GGG   144.309872   3.039782e-33    0.214775    0.223988
# synonymous_CAC   143.592593   4.361793e-33    0.479738    0.439034
# synonymous_CAT   143.592593   4.361793e-33    0.500995    0.401550
# degeneracy_med   133.987202   5.498879e-31    0.328177    0.337485
# synonymous_TTG   130.220145   3.667604e-30    0.170800    0.150685
# codons_CGC       125.844620   3.325261e-29    0.004733    0.005254
# synonymous_CCA   119.636252   7.599225e-28    0.393482    0.351048
# dnt_TT           119.272978   9.126475e-28    0.044069    0.046197
# synonymous_AGA   112.488213   2.793206e-26    0.418444    0.384489
# codons_CCT       111.170133   5.430451e-26    0.017474    0.020423
# codons_TTT       110.283309   8.494080e-26    0.013989    0.014927
# synonymous_CTA   108.928658   1.682333e-25    0.109817    0.117780
# nt_A             105.631786   8.879194e-25    0.290095    0.278836
# dnt_TC           103.774887   2.266600e-24    0.055547    0.059704
# codons_CTC       102.576301   4.150692e-24    0.014007    0.016293
# codons_TAT        99.579579   1.884375e-23    0.010175    0.011077
# synonymous_ATA    97.941328   4.309645e-23    0.256757    0.238234
# codons_GCG        96.580679   8.568032e-23    0.004754    0.005170
# synonymous_CGG    96.172814   1.052807e-22    0.075004    0.076473
# synonymous_GCG    95.664149   1.361233e-22    0.071977    0.065086
# codons_GGA        92.905013   5.486535e-22    0.023185    0.022460
# codons_CCC        87.787236   7.288779e-21    0.014510    0.015994

# %% [markdown]
# Box plots of selected features with Chi2 score above 75. Dots represent selected feature frequencies for every transcripts within class.

# %%
fc.get_boxplot('dnt', 'TA', frqs_dict)

# %%
fc.get_boxplot('codons', 'ATG', frqs_dict)

# %%
fc.get_boxplot('degeneracy', 'low', frqs_dict)

# %%
fc.get_boxplot('dnt', 'TG', frqs_dict)
